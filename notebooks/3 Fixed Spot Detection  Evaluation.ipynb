# %% [markdown]
# # Fixed Spot Detection Evaluation
#
# We are now looking into the `FixedSpotDetectionEvaluation` which inherits `MeanImageEvaluation`

# %%
# %load_ext autoreload
# %autoreload 2
    
import numpy as np
from matplotlib import pyplot as plt
from pyeval import GzipPickleDataset, FixedSpotDetectionEvaluation

# %matplotlib ipympl
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset = GzipPickleDataset("/tmp/AA_clock_spect_0G")
len(dataset)
# Out:
# 767

# %%
evaluation = FixedSpotDetectionEvaluation(spot_num=16, spot_radius=3)
evaluation.evaluate(dataset, plot=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
evaluation.spot_positions
# Out:
# array([[ 21.50080057,  13.9906036 ],
#        [ 22.55373385,  33.09809463],
#        [ 23.04217591,  51.76018771],
#        [ 23.9951445 ,  70.75291703],
#        [ 24.96796515,  89.60455589],
#        [ 25.4916913 , 108.48883085],
#        [ 26.19629162, 127.28863655],
#        [ 26.83060805, 146.15186403],
#        [ 27.59619303, 165.00528715],
#        [ 28.66611621, 184.15884458],
#        [ 29.40819366, 202.98675258],
#        [ 30.08406288, 221.97431321],
#        [ 30.78096526, 240.60768693],
#        [ 31.79870594, 259.49568822],
#        [ 32.65388248, 278.23888016],
#        [ 33.19868498, 297.2680386 ]])

# %%
evaluation.spot_counts.shape
# Out:
# (767, 2, 16)
